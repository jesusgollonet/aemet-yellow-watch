# %%
# !pip install opencv-contrib-python matplotlib numpy
# Out:
# ...
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# ...
#   Using cached matplotlib-3.9.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached numpy-2.0.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (162 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (63.7 MB)
# Using cached matplotlib-3.9.1-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
# Using cached numpy-2.0.1-cp312-cp312-macosx_14_0_arm64.whl (5.0 MB)
# ...

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
img = cv.imread('images/2024072400+108_aewam_alb_martot.png')
img2 = cv.imread('images/pre/2024072400+060_aewam_alb_martot.png')
ax[0].imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
ax[1].imshow(cv.cvtColor(img2, cv.COLOR_BGR2RGB))

# %%
diff = cv.absdiff(img, img2)
ptt.imshow(cv.cvtColor(diff, cv.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 diff = cv.absdiff(img, img2)
# ----> 2 ptt.imshow(cv.cvtColor(diff, cv.COLOR_BGR2RGB))
#
# NameError: name 'ptt' is not defined
